# %% [markdown]
# # **Devumi**- EfficientNetB0 (transfer + simple fine-tune)

# %%
# Check GPU
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Basic deps for the split script + training
# !pip -q install pandas scikit-learn tqdm

# %%
#1) Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Install gdown for downloading from Google Drive
# !pip install gdown

# File IDs from the shared links
ZIP1_ID = "1b48IDnMERZqxAUvateocerBPG5pYrcEZ"
ZIP2_ID = "1yI1dv5g3aZtcCoF9TiNp0MGJ43PXDbbX"
META_ID = "1z6UjvF4cl10ckRBt8vxAH7DNFSlifMLR"

# Local working area on Colab SSD
WORK     = "/content/work"
RAW_DIR  = f"{WORK}/raw"
EXTRACT  = f"{WORK}/ham10000_extracted"
DATA_DIR = f"{WORK}/data"

import os, subprocess, pathlib
os.makedirs(RAW_DIR, exist_ok=True)
os.makedirs(EXTRACT, exist_ok=True)
os.makedirs(DATA_DIR, exist_ok=True)

# Download files using gdown
import gdown

print("Downloading HAM10000_images_part_1.zip...")
gdown.download(f"https://drive.google.com/uc?id={ZIP1_ID}", f"{RAW_DIR}/HAM10000_images_part_1.zip", quiet=False)

print("Downloading HAM10000_images_part_2.zip...")
gdown.download(f"https://drive.google.com/uc?id={ZIP2_ID}", f"{RAW_DIR}/HAM10000_images_part_2.zip", quiet=False)

print("Downloading HAM10000_metadata.csv...")
gdown.download(f"https://drive.google.com/uc?id={META_ID}", f"{RAW_DIR}/HAM10000_metadata.csv", quiet=False)

print("Download completed! Local RAW_DIR contents:")
print(subprocess.getoutput(f'ls -lh "{RAW_DIR}"'))
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.10.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading HAM10000_images_part_1.zip...
# Downloading...
# From (original): https://drive.google.com/uc?id=1b48IDnMERZqxAUvateocerBPG5pYrcEZ
# From (redirected): https://drive.google.com/uc?id=1b48IDnMERZqxAUvateocerBPG5pYrcEZ&confirm=t&uuid=2cbf0659-7637-47a4-a1c0-262cce40b4e2
# To: /content/work/raw/HAM10000_images_part_1.zip
# 100%|██████████| 1.37G/1.37G [00:17<00:00, 76.1MB/s]
# Downloading HAM10000_images_part_2.zip...
# Downloading...
# From (original): https://drive.google.com/uc?id=1yI1dv5g3aZtcCoF9TiNp0MGJ43PXDbbX
# From (redirected): https://drive.google.com/uc?id=1yI1dv5g3aZtcCoF9TiNp0MGJ43PXDbbX&confirm=t&uuid=15541e39-d88a-4cb2-a8d5-484bac2d02a8
# To: /content/work/raw/HAM10000_images_part_2.zip
# 100%|██████████| 1.40G/1.40G [00:16<00:00, 86.1MB/s]
# Downloading HAM10000_metadata.csv...
# Downloading...
# From: https://drive.google.com/uc?id=1z6UjvF4cl10ckRBt8vxAH7DNFSlifMLR
# To: /content/work/raw/HAM10000_metadata.csv
# 100%|██████████| 563k/563k [00:00<00:00, 122MB/s]
# Download completed! Local RAW_DIR contents:
# total 2.6G
# -rw-r--r-- 1 root root 1.3G Oct  2 03:41 HAM10000_images_part_1.zip
# -rw-r--r-- 1 root root 1.4G Oct  2 03:18 HAM10000_images_part_2.zip
# -rw-r--r-- 1 root root 551K Oct  2 02:50 HAM10000_metadata.csv

# %%
import os, json, time, argparse
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

# %%
# !mkdir -p /content/scripts

# %%
# %%writefile /content/scripts/split_ham10000.py
#!/usr/bin/env python3
import argparse, os, shutil, zipfile
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def unzip_if_needed(zip_path: Path, extract_dir: Path):
    extract_dir.mkdir(parents=True, exist_ok=True)
    # If any jpgs already exist anywhere under extract_dir, skip
    if any(extract_dir.rglob("*.jpg")):
        print(f"[skip] Images already present under: {extract_dir}")
        return
    assert zip_path.exists(), f"Missing: {zip_path}"
    print(f"[unzip] {zip_path.name} -> {extract_dir}")
    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(extract_dir)

def index_images(img_root: Path):
    """
    Build a dict: image_id (without .jpg) -> full path
    Recurses under img_root to handle both 'HAM10000_images' and '..._part_1/part_2' layouts.
    """
    mapping = {}
    for p in img_root.rglob("*.jpg"):
        mapping[p.stem] = str(p)
    return mapping

def build_splits(meta_csv: Path, img_root: Path, train_pct: float, val_pct: float, test_pct: float, seed: int):
    assert abs((train_pct + val_pct + test_pct) - 1.0) < 1e-6, "Splits must sum to 1.0"
    meta = pd.read_csv(meta_csv)
    img_map = index_images(img_root)
    meta["image_path"] = meta["image_id"].map(img_map)
    meta = meta.dropna(subset=["image_path"]).copy()

    # quick sanity
    print(f"[info] Found {len(img_map)} jpgs under {img_root}")
    print(f"[info] Matched rows with metadata: {len(meta)}")

    train_df, temp_df = train_test_split(
        meta, test_size=1.0-train_pct, stratify=meta["dx"], random_state=seed
    )
    test_rel = test_pct / (val_pct + test_pct)
    val_df, test_df = train_test_split(
        temp_df, test_size=test_rel, stratify=temp_df["dx"], random_state=seed
    )
    return train_df, val_df, test_df, sorted(meta["dx"].unique())

def materialize_split(df: pd.DataFrame, split_name: str, out_root: Path):
    base = out_root / split_name
    base.mkdir(parents=True, exist_ok=True)
    for cls in sorted(df["dx"].unique()):
        (base / cls).mkdir(parents=True, exist_ok=True)
    for _, r in tqdm(df.iterrows(), total=len(df), desc=f"{split_name:>5}", unit="img"):
        src = Path(r["image_path"])
        dst = base / r["dx"] / src.name
        if not dst.exists():
            shutil.copy2(src, dst)

def print_counts(data_dir: Path):
    for split in ["train", "val", "test"]:
        base = data_dir / split
        if base.exists():
            counts = {
                d.name: len(list((base / d).glob("*")))
                for d in base.iterdir() if d.is_dir()
            }
            print(split, counts)

def main():
    p = argparse.ArgumentParser()
    p.add_argument("--project_dir", default=".")
    p.add_argument("--train", type=float, default=0.8)
    p.add_argument("--val",   type=float, default=0.1)
    p.add_argument("--test",  type=float, default=0.1)
    p.add_argument("--seed",  type=int, default=42)
    p.add_argument("--clean", action="store_true")
    args = p.parse_args()

    project = Path(args.project_dir).resolve()
    raw_dir  = project / "raw"
    data_dir = project / "data"
    extract  = project / "ham10000_extracted"   # we recurse under this folder
    imgs_root = extract                         # <-- recursive root

    part1 = raw_dir / "HAM10000_images_part_1.zip"
    part2 = raw_dir / "HAM10000_images_part_2.zip"
    meta  = raw_dir / "HAM10000_metadata.csv"

    extract.mkdir(parents=True, exist_ok=True)
    data_dir.mkdir(parents=True, exist_ok=True)

    unzip_if_needed(part1, extract)
    unzip_if_needed(part2, extract)

    train_df, val_df, test_df, classes = build_splits(
        meta, imgs_root, args.train, args.val, args.test, args.seed
    )

    if args.clean:
        for s in ["train", "val", "test"]:
            target = data_dir / s
            if target.exists():
                shutil.rmtree(target)

    materialize_split(train_df, "train", data_dir)
    materialize_split(val_df, "val", data_dir)
    materialize_split(test_df, "test", data_dir)
    print_counts(data_dir)
    print("[done] Data ready at:", data_dir)

if __name__ == "__main__":
    main()
# Out:
# Writing /content/scripts/split_ham10000.py

# %%
# !python /content/scripts/split_ham10000.py \
  --project_dir "/content/work" \
  --train 0.8 --val 0.1 --test 0.1 --seed 42 --clean
# Out:
# [unzip] HAM10000_images_part_1.zip -> /content/work/ham10000_extracted
# [skip] Images already present under: /content/work/ham10000_extracted
# [info] Found 5000 jpgs under /content/work/ham10000_extracted
# [info] Matched rows with metadata: 5000
# train: 100% 4000/4000 [00:05<00:00, 754.32img/s]
#   val: 100% 500/500 [00:00<00:00, 1145.79img/s]
#  test: 100% 500/500 [00:00<00:00, 939.14img/s]
# train {'vasc': 52, 'mel': 348, 'akiec': 146, 'nv': 2745, 'bcc': 213, 'bkl': 451, 'df': 45}
# val {'vasc': 7, 'mel': 43, 'akiec': 19, 'nv': 343, 'bcc': 27, 'bkl': 56, 'df': 5}
# test {'vasc': 6, 'mel': 44, 'akiec': 18, 'nv': 343, 'bcc': 26, 'bkl': 57, 'df': 6}
# [done] Data ready at: /content/work/data

# %%
#Quick sanity check:
import os
for split in ("train","val","test"):
    base = os.path.join("/content/work/data", split)
    classes = [d for d in sorted(os.listdir(base)) if os.path.isdir(os.path.join(base,d))]
    counts = {c: len(os.listdir(os.path.join(base,c))) for c in classes}
    print(split, counts)
# Out:
# train {'akiec': 146, 'bcc': 213, 'bkl': 451, 'df': 45, 'mel': 348, 'nv': 2745, 'vasc': 52}
# val {'akiec': 19, 'bcc': 27, 'bkl': 56, 'df': 5, 'mel': 43, 'nv': 343, 'vasc': 7}
# test {'akiec': 18, 'bcc': 26, 'bkl': 57, 'df': 6, 'mel': 44, 'nv': 343, 'vasc': 6}

# %%
import os
print("Exists:", os.path.isdir("/content/work/data"))
print("Splits:", os.listdir("/content/work/data"))
# Out:
# Exists: True
# Splits: ['val', 'train', 'test']

# %%
# make sure the folder exists
# !mkdir -p /content/members

# %%
# %%writefile /content/members/run_effb0.py
#!/usr/bin/env python3
import os, json, time, argparse, csv, datetime
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

MODEL_DIR = "efficientnet"   # <- model-specific folder & master CSV

def get_datasets(data_dir, img_size=(224,224), batch=32, seed=42, binary=False):
    def loader(split, shuffle):
        return tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir, split),
            image_size=img_size, batch_size=batch, seed=seed, shuffle=shuffle
        )
    ds_train = loader("train", True); ds_val = loader("val", False); ds_test = loader("test", False)
    class_names = ds_train.class_names

    aug = keras.Sequential([
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.05),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1),
    ])
    ds_train = ds_train.map(lambda x,y:(aug(x),y), num_parallel_calls=tf.data.AUTOTUNE)
    ds_train = ds_train.cache().prefetch(tf.data.AUTOTUNE)
    ds_val   = ds_val.cache().prefetch(tf.data.AUTOTUNE)
    ds_test  = ds_test.cache().prefetch(tf.data.AUTOTUNE)
    return ds_train, ds_val, ds_test, class_names, bool(binary)

def compute_class_weights(ds, n_classes):
    counts = np.zeros(n_classes, dtype=np.int64)
    for _, y in ds.unbatch():
        counts[int(y.numpy())] += 1

    manual_weights = {
        0: 3.0,  # akiec - boost recall
        1: 1.5,  # bcc - decent but can improve
        2: 1.2,  # bkl - decent but can improve
        3: 2.5,  # df - small class, protect it
        4: 2.0,  # mel - boost precision
        5: 0.7,  # nv - reduce dominance
        6: 2.0   # vasc - small class, protect it
    }

    return manual_weights

def build_model(num_classes, img_size=(224,224), binary=False):
    from tensorflow.keras.applications.efficientnet import EfficientNetB0, preprocess_input
    inp = keras.Input(shape=(*img_size,3))
    x = preprocess_input(inp)
    base = EfficientNetB0(include_top=False, weights="imagenet", input_tensor=x)
    x = layers.GlobalAveragePooling2D()(base.output)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(1, activation="sigmoid", dtype="float32")(x) if binary \
          else layers.Dense(num_classes, activation="softmax", dtype="float32")(x)
    return keras.Model(inp, out), base

def compile_and_fit(model, train_ds, val_ds, *, loss, lr, epochs, class_weight, ckpt_path):
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr),
                  loss=loss, metrics=["accuracy"])
    os.makedirs(os.path.dirname(ckpt_path), exist_ok=True)
    cbs = [
        keras.callbacks.ModelCheckpoint(ckpt_path, save_best_only=True,
                                        monitor="val_accuracy", mode="max"),
        keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True,
                                      monitor="val_accuracy", mode="max"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3,
                                          patience=2, min_lr=1e-6, verbose=1),
    ]
    hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs,
                     class_weight=class_weight, callbacks=cbs)
    return {k: [float(v) for v in vals] for k, vals in hist.history.items()}

def eval_save(model, ds_test, names, out_dir, binary=False):
    y_true, y_pred = [], []
    for x, y in ds_test:
        p = model.predict(x, verbose=0)
        yp = (p.reshape(-1) >= 0.5).astype(int) if binary else p.argmax(axis=1)
        y_true += y.numpy().tolist(); y_pred += yp.tolist()
    y_true = np.array(y_true); y_pred = np.array(y_pred)

    acc = float(accuracy_score(y_true, y_pred))
    f1  = float(f1_score(y_true, y_pred, average=("binary" if binary else "macro")))
    rep = classification_report(y_true, y_pred, target_names=names)
    cm  = confusion_matrix(y_true, y_pred).tolist()

    os.makedirs(out_dir, exist_ok=True)
    json.dump({"accuracy": acc, "macro_f1": f1, "confusion_matrix": cm},
              open(os.path.join(out_dir,"metrics.json"),"w"), indent=2)
    open(os.path.join(out_dir,"classification_report.txt"),"w").write(rep)
    json.dump(names, open(os.path.join(out_dir,"classes.json"),"w"), indent=2)
    print(rep); print("Saved:", out_dir)
    return acc, f1

def write_epoch_csv(history, path_csv):
    import pandas as pd
    n = max(len(history.get("accuracy",[])), len(history.get("loss",[])))
    rows = [{
        "epoch": i+1,
        "accuracy": history.get("accuracy",[None]*n)[i],
        "loss": history.get("loss",[None]*n)[i],
        "val_accuracy": history.get("val_accuracy",[None]*n)[i],
        "val_loss": history.get("val_loss",[None]*n)[i],
    } for i in range(n)]
    pd.DataFrame(rows).to_csv(path_csv, index=False)

def append_master_row(master_csv, row):
    headers = ["timestamp","run_name","data","img_size","batch","warmup","epochs",
               "unfreeze","base_lr","ft_lr","binary","best_val_acc","best_val_loss",
               "test_acc","test_macro_f1"]
    os.makedirs(os.path.dirname(master_csv), exist_ok=True)
    new = not os.path.isfile(master_csv)
    with open(master_csv, "a", newline="") as f:
        w = csv.DictWriter(f, fieldnames=headers)
        if new: w.writeheader()
        w.writerow({k: row.get(k) for k in headers})

def main(a):
    run = a.run_name or time.strftime("%Y%m%d-%H%M%S")
    out_root = a.out_dir or "runs"
    # ----- model-specific folder -----
    model_root = os.path.join(out_root, MODEL_DIR)
    out = os.path.join(model_root, run)
    os.makedirs(out, exist_ok=True)

    ds_tr, ds_va, ds_te, names, binary = get_datasets(a.data, (a.size, a.size), a.batch, binary=bool(a.binary))
    ncls = 2 if binary else len(names)
    class_weight = compute_class_weights(ds_tr, ncls)

    model, base = build_model(ncls, (a.size, a.size), binary)
    loss = "binary_crossentropy" if binary else keras.losses.SparseCategoricalCrossentropy()

    # Phase 1: warmup
    base.trainable = False
    hist_warm = compile_and_fit(model, ds_tr, ds_va, loss=loss, lr=a.base_lr,
                                epochs=max(1, a.warmup), class_weight=class_weight,
                                ckpt_path=os.path.join(out, "best.keras"))

    # Phase 2: fine-tune (partial unfreeze)
    base.trainable = True
    if a.unfreeze > 0 and a.unfreeze < len(base.layers):
        for l in base.layers[:-a.unfreeze]:
            l.trainable = False
    hist_ft = compile_and_fit(model, ds_tr, ds_va, loss=loss, lr=a.ft_lr,
                              epochs=a.epochs, class_weight=class_weight,
                              ckpt_path=os.path.join(out, "best.keras"))

    # Save histories
    history = {}
    for k in set(list(hist_warm.keys()) + list(hist_ft.keys())):
        history[k] = (hist_warm.get(k, []) + hist_ft.get(k, []))
    json.dump(history, open(os.path.join(out,"history.json"),"w"), indent=2)
    write_epoch_csv(history, os.path.join(out,"history_epoch.csv"))

    # Evaluate & save reports
    test_acc, test_f1 = eval_save(model, ds_te, names, out, binary)

    # ----- model-specific master CSV -----
    best_idx = int(np.nanargmax(history.get("val_accuracy",[np.nan])))
    best_val_acc  = float(history["val_accuracy"][best_idx]) if "val_accuracy" in history else None
    best_val_loss = float(history["val_loss"][best_idx]) if "val_loss" in history else None
    master_csv = os.path.join(model_root, "experiments_master.csv")
    append_master_row(master_csv, {
        "timestamp": datetime.datetime.now().isoformat(timespec="seconds"),
        "run_name": run,
        "data": a.data, "img_size": a.size, "batch": a.batch,
        "warmup": a.warmup, "epochs": a.epochs, "unfreeze": a.unfreeze,
        "base_lr": a.base_lr, "ft_lr": a.ft_lr, "binary": int(a.binary),
        "best_val_acc": best_val_acc, "best_val_loss": best_val_loss,
        "test_acc": test_acc, "test_macro_f1": test_f1
    })
    print(f"[master] Appended summary to: {master_csv}")

if __name__ == "__main__":
    ap = argparse.ArgumentParser()
    ap.add_argument("--data", required=True)
    ap.add_argument("--epochs", type=int, default=20)
    ap.add_argument("--warmup", type=int, default=3)
    ap.add_argument("--size", type=int, default=224)
    ap.add_argument("--batch", type=int, default=32)
    ap.add_argument("--base_lr", type=float, default=1e-3)
    ap.add_argument("--ft_lr", type=float, default=3e-5)
    ap.add_argument("--unfreeze", type=int, default=80)
    ap.add_argument("--binary", type=int, default=0)
    ap.add_argument("--run_name", default="")
    ap.add_argument("--out_dir", default="runs")
    a = ap.parse_args(); main(a)
# Out:
# Writing /content/members/run_effb0.py

# %%
# smaller batch
# !python /content/members/run_effb0.py \
  --data "/content/work/data" \
  --epochs 25 --warmup 3 --unfreeze 40 \
  --batch 16 --base_lr 1e-3 --ft_lr 3e-5 \
  --out_dir /content/runs --run_name e25_b16
# Out:
# 2025-10-11 19:18:51.008794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760210331.029351   24613 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760210331.036181   24613 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760210331.051195   24613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760210331.051222   24613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760210331.051226   24613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760210331.051232   24613 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 4000 files belonging to 7 classes.
# 2025-10-11 19:18:56.000398: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1760210336.000923   24613 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Found 500 files belonging to 7 classes.
# Found 500 files belonging to 7 classes.
# Epoch 1/3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760210431.904215   24655 service.cc:152] XLA service 0x7cc22414cd60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760210431.904247   24655 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760210433.819330   24655 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2025-10-11 19:20:44.072911: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.143 = (f32[16,480,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,480,14,14]{3,2,1,0} %bitcast.28353, f32[480,1,5,5]{3,2,1,0} %bitcast.28357), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=480, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:20:45.229080: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.157348305s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.143 = (f32[16,480,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,480,14,14]{3,2,1,0} %bitcast.28353, f32[480,1,5,5]{3,2,1,0} %bitcast.28357), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=480, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:20:45.803511: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:46.086424: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:46.392416: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:46.461620: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[16,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,672,14,14]{3,2,1,0} %bitcast.28555, f32[672,1,5,5]{3,2,1,0} %bitcast.28559), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:20:46.534660: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.073141011s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[16,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,672,14,14]{3,2,1,0} %bitcast.28555, f32[672,1,5,5]{3,2,1,0} %bitcast.28559), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:20:47.584026: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:47.966282: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[16,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1152,7,7]{3,2,1,0} %bitcast.30748, f32[1152,1,5,5]{3,2,1,0} %bitcast.30752), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:20:47.986185: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:48.414264: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:48.554023: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.587840489s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[16,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1152,7,7]{3,2,1,0} %bitcast.30748, f32[1152,1,5,5]{3,2,1,0} %bitcast.30752), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:20:49.729827: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:50.128909: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:20:50.219470: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[16,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1152,7,7]{3,2,1,0} %bitcast.33732, f32[1152,1,3,3]{3,2,1,0} %bitcast.33736), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:20:50.255769: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.036392075s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[16,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,1152,7,7]{3,2,1,0} %bitcast.33732, f32[1152,1,3,3]{3,2,1,0} %bitcast.33736), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1760210457.469877   24655 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6346 - loss: 1.50942025-10-11 19:21:35.147901: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.131 = (f32[4,240,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,240,28,28]{3,2,1,0} %bitcast.8022, f32[240,1,5,5]{3,2,1,0} %bitcast.8026), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=240, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block3b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:35.654018: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.507231806s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.131 = (f32[4,240,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,240,28,28]{3,2,1,0} %bitcast.8022, f32[240,1,5,5]{3,2,1,0} %bitcast.8026), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=240, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block3b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:38.709658: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.137 = (f32[4,480,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,480,14,14]{3,2,1,0} %bitcast.8434, f32[480,1,3,3]{3,2,1,0} %bitcast.8438), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=480, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block4b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:40.181373: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.471816385s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.137 = (f32[4,480,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,480,14,14]{3,2,1,0} %bitcast.8434, f32[480,1,3,3]{3,2,1,0} %bitcast.8438), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=480, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block4b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:41.970275: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:42.474078: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:42.526284: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[4,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,672,14,14]{3,2,1,0} %bitcast.9052, f32[672,1,5,5]{3,2,1,0} %bitcast.9056), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:42.791279: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:43.085820: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:43.509136: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:43.889849: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:44.305662: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:44.697450: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:45.095306: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:45.588899: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:45.850886: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 4.324693738s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[4,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,672,14,14]{3,2,1,0} %bitcast.9052, f32[672,1,5,5]{3,2,1,0} %bitcast.9056), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:47.406067: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[4,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1152,7,7]{3,2,1,0} %bitcast.9671, f32[1152,1,5,5]{3,2,1,0} %bitcast.9675), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:47.411047: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:48.125011: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:48.676227: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:48.944888: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.538937456s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[4,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1152,7,7]{3,2,1,0} %bitcast.9671, f32[1152,1,5,5]{3,2,1,0} %bitcast.9675), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:50.783392: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:51.038764: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[4,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1152,7,7]{3,2,1,0} %bitcast.10292, f32[1152,1,3,3]{3,2,1,0} %bitcast.10296), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 19:21:51.443299: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:51.998146: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 19:21:52.236135: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.197457509s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[4,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,1152,7,7]{3,2,1,0} %bitcast.10292, f32[1152,1,3,3]{3,2,1,0} %bitcast.10296), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 236ms/step - accuracy: 0.6348 - loss: 1.5088 - val_accuracy: 0.7000 - val_loss: 0.8095 - learning_rate: 0.0010
# Epoch 2/3
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7045 - loss: 1.1345 - val_accuracy: 0.7180 - val_loss: 0.7497 - learning_rate: 0.0010
# Epoch 3/3
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.7216 - loss: 1.0430 - val_accuracy: 0.7260 - val_loss: 0.7156 - learning_rate: 0.0010
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 121ms/step - accuracy: 0.4915 - loss: 1.4703 - val_accuracy: 0.7460 - val_loss: 0.7469 - learning_rate: 3.0000e-05
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 96ms/step - accuracy: 0.7334 - loss: 1.0376 - val_accuracy: 0.7620 - val_loss: 0.7002 - learning_rate: 3.0000e-05
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 90ms/step - accuracy: 0.7775 - loss: 0.8891 - val_accuracy: 0.7600 - val_loss: 0.6692 - learning_rate: 3.0000e-05
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step - accuracy: 0.7953 - loss: 0.8014 - val_accuracy: 0.7620 - val_loss: 0.6437 - learning_rate: 3.0000e-05
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 94ms/step - accuracy: 0.8139 - loss: 0.7363 - val_accuracy: 0.7720 - val_loss: 0.6298 - learning_rate: 3.0000e-05
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 88ms/step - accuracy: 0.8411 - loss: 0.6567 - val_accuracy: 0.7740 - val_loss: 0.6104 - learning_rate: 3.0000e-05
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 93ms/step - accuracy: 0.8377 - loss: 0.6187 - val_accuracy: 0.7740 - val_loss: 0.6165 - learning_rate: 3.0000e-05
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 92ms/step - accuracy: 0.8598 - loss: 0.5345 - val_accuracy: 0.8040 - val_loss: 0.5962 - learning_rate: 3.0000e-05
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.8730 - loss: 0.5165 - val_accuracy: 0.8000 - val_loss: 0.5996 - learning_rate: 3.0000e-05
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8925 - loss: 0.4564
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.8925 - loss: 0.4565 - val_accuracy: 0.7980 - val_loss: 0.6074 - learning_rate: 3.0000e-05
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.9037 - loss: 0.4194 - val_accuracy: 0.8040 - val_loss: 0.6033 - learning_rate: 9.0000e-06
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9070 - loss: 0.4149
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.9070 - loss: 0.4149 - val_accuracy: 0.8040 - val_loss: 0.6011 - learning_rate: 9.0000e-06
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.9174 - loss: 0.3851 - val_accuracy: 0.8000 - val_loss: 0.6033 - learning_rate: 2.7000e-06
#               precision    recall  f1-score   support
#
#        akiec       0.60      0.33      0.43        18
#          bcc       0.70      0.54      0.61        26
#          bkl       0.57      0.70      0.63        57
#           df       0.67      0.33      0.44         6
#          mel       0.38      0.43      0.40        44
#           nv       0.91      0.91      0.91       343
#         vasc       0.75      0.50      0.60         6
#
#     accuracy                           0.79       500
#    macro avg       0.65      0.54      0.58       500
# weighted avg       0.80      0.79      0.79       500
#
# Saved: /content/runs/efficientnet/e25_b16
# [master] Appended summary to: /content/runs/efficientnet/experiments_master.csv

# %%
# baseline run
# !python /content/members/run_effb0.py \
  --data "/content/work/data" \
  --epochs 40 --warmup 5 --unfreeze 80 \
  --batch 32 --base_lr 1e-3 --ft_lr 3e-5 \
  --out_dir /content/runs --run_name e40_b32
# Out:
# 2025-10-11 18:43:40.996252: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760208221.016395   14393 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760208221.022341   14393 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760208221.037606   14393 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760208221.037640   14393 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760208221.037644   14393 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760208221.037653   14393 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 4000 files belonging to 7 classes.
# 2025-10-11 18:43:45.196619: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1760208225.197026   14393 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Found 500 files belonging to 7 classes.
# Found 500 files belonging to 7 classes.
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760208294.040132   14433 service.cc:152] XLA service 0x7bbee4112ca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760208294.040165   14433 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760208295.931196   14433 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2025-10-11 18:45:03.591005: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.125 = (f32[32,144,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,144,56,56]{3,2,1,0} %bitcast.23989, f32[144,1,3,3]{3,2,1,0} %bitcast.23993), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=144, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block2b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:04.290230: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.699321891s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.125 = (f32[32,144,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,144,56,56]{3,2,1,0} %bitcast.23989, f32[144,1,3,3]{3,2,1,0} %bitcast.23993), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=144, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block2b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:05.803759: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.131 = (f32[32,240,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,240,28,28]{3,2,1,0} %bitcast.25164, f32[240,1,5,5]{3,2,1,0} %bitcast.25168), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=240, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block3b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:06.203866: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.400186005s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.131 = (f32[32,240,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,240,28,28]{3,2,1,0} %bitcast.25164, f32[240,1,5,5]{3,2,1,0} %bitcast.25168), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=240, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block3b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:09.885064: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.143 = (f32[32,480,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,480,14,14]{3,2,1,0} %bitcast.28353, f32[480,1,5,5]{3,2,1,0} %bitcast.28357), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=480, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:09.954031: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.069062354s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.143 = (f32[32,480,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,480,14,14]{3,2,1,0} %bitcast.28353, f32[480,1,5,5]{3,2,1,0} %bitcast.28357), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=480, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:10.534574: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:10.880969: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:11.180760: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[32,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,672,14,14]{3,2,1,0} %bitcast.28555, f32[672,1,5,5]{3,2,1,0} %bitcast.28559), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:11.266387: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:11.465841: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.285168954s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[32,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,672,14,14]{3,2,1,0} %bitcast.28555, f32[672,1,5,5]{3,2,1,0} %bitcast.28559), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:12.361301: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:12.675336: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:12.840985: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[32,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1152,7,7]{3,2,1,0} %bitcast.30748, f32[1152,1,5,5]{3,2,1,0} %bitcast.30752), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:13.000382: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:13.356549: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:13.737642: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:14.224550: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:14.608880: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:15.015594: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:15.420581: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:15.834701: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:15.991055: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 4.150152595s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[32,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1152,7,7]{3,2,1,0} %bitcast.30748, f32[1152,1,5,5]{3,2,1,0} %bitcast.30752), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:17.564016: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:17.811145: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[32,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1152,7,7]{3,2,1,0} %bitcast.33732, f32[1152,1,3,3]{3,2,1,0} %bitcast.33736), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:18.132548: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:18.687120: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:19.110870: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:19.476130: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:19.620845: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.809791464s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[32,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1152,7,7]{3,2,1,0} %bitcast.33732, f32[1152,1,3,3]{3,2,1,0} %bitcast.33736), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# I0000 00:00:1760208325.865819   14433 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6356 - loss: 1.52332025-10-11 18:45:54.756964: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.125 = (f32[20,144,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,144,56,56]{3,2,1,0} %bitcast.7610, f32[144,1,3,3]{3,2,1,0} %bitcast.7614), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=144, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block2b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:54.770317: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.0134285s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.125 = (f32[20,144,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,144,56,56]{3,2,1,0} %bitcast.7610, f32[144,1,3,3]{3,2,1,0} %bitcast.7614), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=144, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block2b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:45:59.234950: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:59.581051: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:59.908683: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:45:59.920582: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[20,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,672,14,14]{3,2,1,0} %bitcast.9052, f32[672,1,5,5]{3,2,1,0} %bitcast.9056), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:46:00.082752: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.162254033s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.146 = (f32[20,672,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,672,14,14]{3,2,1,0} %bitcast.9052, f32[672,1,5,5]{3,2,1,0} %bitcast.9056), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block5b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:46:01.082878: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:46:01.469442: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:46:01.526678: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[20,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,1152,7,7]{3,2,1,0} %bitcast.9671, f32[1152,1,5,5]{3,2,1,0} %bitcast.9675), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:46:01.844907: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:46:01.989533: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.462961239s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.155 = (f32[20,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,1152,7,7]{3,2,1,0} %bitcast.9671, f32[1152,1,5,5]{3,2,1,0} %bitcast.9675), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block6b_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:46:03.340572: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:46:03.723996: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[20,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,1152,7,7]{3,2,1,0} %bitcast.10292, f32[1152,1,3,3]{3,2,1,0} %bitcast.10296), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:46:03.838884: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:46:04.017145: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.293243753s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.164 = (f32[20,1152,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,1152,7,7]{3,2,1,0} %bitcast.10292, f32[1152,1,3,3]{3,2,1,0} %bitcast.10296), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNative" op_name="functional_1_1/block7a_dwconv_1/depthwise" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 85s 345ms/step - accuracy: 0.6359 - loss: 1.5221 - val_accuracy: 0.6720 - val_loss: 0.8989 - learning_rate: 0.0010
# Epoch 2/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 138ms/step - accuracy: 0.6960 - loss: 1.1615 - val_accuracy: 0.7040 - val_loss: 0.8301 - learning_rate: 0.0010
# Epoch 3/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 14s 116ms/step - accuracy: 0.7099 - loss: 1.0739 - val_accuracy: 0.7080 - val_loss: 0.8115 - learning_rate: 0.0010
# Epoch 4/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 15s 120ms/step - accuracy: 0.7187 - loss: 1.0242 - val_accuracy: 0.7240 - val_loss: 0.7754 - learning_rate: 0.0010
# Epoch 5/5
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 15s 120ms/step - accuracy: 0.7417 - loss: 0.9639 - val_accuracy: 0.7260 - val_loss: 0.7590 - learning_rate: 0.0010
# Epoch 1/40
# 2025-10-11 18:47:35.463583: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:47:35.746965: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:47:36.016223: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:47:36.157152: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=2} for conv %cudnn-conv.228 = (f32[32,672,17,17]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,672,21,21]{3,2,1,0} %bitcast.53631, f32[672,1,5,5]{3,2,1,0} %bitcast.53639), window={size=5x5}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNativeBackpropInput" op_name="gradient_tape/functional_1_1/block6a_dwconv_1/depthwise/DepthwiseConv2dNativeBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:47:36.324003: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:47:36.621929: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:47:36.896391: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-11 18:47:37.018007: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.860954547s
# Trying algorithm eng3{k11=2} for conv %cudnn-conv.228 = (f32[32,672,17,17]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,672,21,21]{3,2,1,0} %bitcast.53631, f32[672,1,5,5]{3,2,1,0} %bitcast.53639), window={size=5x5}, dim_labels=bf01_oi01->bf01, feature_group_count=672, custom_call_target="__cudnn$convForward", metadata={op_type="DepthwiseConv2dNativeBackpropInput" op_name="gradient_tape/functional_1_1/block6a_dwconv_1/depthwise/DepthwiseConv2dNativeBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:47:39.735604: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng17{k25=2} for conv %cudnn-conv-bw-filter.23 = (f32[1152,1,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1152,7,7]{3,2,1,0} %bitcast.55053, f32[32,1152,7,7]{3,2,1,0} %bitcast.55055), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="DepthwiseConv2dNativeBackpropFilter" op_name="gradient_tape/functional_1_1/block6b_dwconv_1/depthwise/DepthwiseConv2dNativeBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2025-10-11 18:47:39.867417: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.131895573s
# Trying algorithm eng17{k25=2} for conv %cudnn-conv-bw-filter.23 = (f32[1152,1,5,5]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,1152,7,7]{3,2,1,0} %bitcast.55053, f32[32,1152,7,7]{3,2,1,0} %bitcast.55055), window={size=5x5 pad=2_2x2_2}, dim_labels=bf01_oi01->bf01, feature_group_count=1152, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="DepthwiseConv2dNativeBackpropFilter" op_name="gradient_tape/functional_1_1/block6b_dwconv_1/depthwise/DepthwiseConv2dNativeBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 73s 254ms/step - accuracy: 0.3867 - loss: 1.6669 - val_accuracy: 0.7380 - val_loss: 0.7624 - learning_rate: 3.0000e-05
# Epoch 2/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 25s 197ms/step - accuracy: 0.7220 - loss: 1.0640 - val_accuracy: 0.7480 - val_loss: 0.7037 - learning_rate: 3.0000e-05
# Epoch 3/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 28s 224ms/step - accuracy: 0.7608 - loss: 0.8882 - val_accuracy: 0.7600 - val_loss: 0.6707 - learning_rate: 3.0000e-05
# Epoch 4/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 26s 207ms/step - accuracy: 0.8032 - loss: 0.7706 - val_accuracy: 0.7700 - val_loss: 0.6394 - learning_rate: 3.0000e-05
# Epoch 5/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 23s 184ms/step - accuracy: 0.8331 - loss: 0.6573 - val_accuracy: 0.7680 - val_loss: 0.6330 - learning_rate: 3.0000e-05
# Epoch 6/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 26s 207ms/step - accuracy: 0.8517 - loss: 0.5987 - val_accuracy: 0.7760 - val_loss: 0.6139 - learning_rate: 3.0000e-05
# Epoch 7/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 24s 189ms/step - accuracy: 0.8653 - loss: 0.5435 - val_accuracy: 0.7780 - val_loss: 0.6199 - learning_rate: 3.0000e-05
# Epoch 8/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8885 - loss: 0.4719
# Epoch 8: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 23s 186ms/step - accuracy: 0.8885 - loss: 0.4718 - val_accuracy: 0.7860 - val_loss: 0.6186 - learning_rate: 3.0000e-05
# Epoch 9/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 23s 185ms/step - accuracy: 0.9096 - loss: 0.4025 - val_accuracy: 0.7900 - val_loss: 0.6162 - learning_rate: 9.0000e-06
# Epoch 10/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9140 - loss: 0.3850
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 177ms/step - accuracy: 0.9140 - loss: 0.3851 - val_accuracy: 0.7900 - val_loss: 0.6186 - learning_rate: 9.0000e-06
# Epoch 11/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 30s 244ms/step - accuracy: 0.9155 - loss: 0.3634 - val_accuracy: 0.7920 - val_loss: 0.6202 - learning_rate: 2.7000e-06
# Epoch 12/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9134 - loss: 0.3725
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1e-06.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 33s 261ms/step - accuracy: 0.9134 - loss: 0.3725 - val_accuracy: 0.7940 - val_loss: 0.6178 - learning_rate: 2.7000e-06
# Epoch 13/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 28s 227ms/step - accuracy: 0.9131 - loss: 0.3683 - val_accuracy: 0.7940 - val_loss: 0.6197 - learning_rate: 1.0000e-06
# Epoch 14/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - accuracy: 0.9199 - loss: 0.3616 - val_accuracy: 0.7920 - val_loss: 0.6203 - learning_rate: 1.0000e-06
# Epoch 15/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 22s 175ms/step - accuracy: 0.9198 - loss: 0.3634 - val_accuracy: 0.7940 - val_loss: 0.6191 - learning_rate: 1.0000e-06
# Epoch 16/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 25s 200ms/step - accuracy: 0.9169 - loss: 0.3617 - val_accuracy: 0.7920 - val_loss: 0.6218 - learning_rate: 1.0000e-06
# Epoch 17/40
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.9199 - loss: 0.3534 - val_accuracy: 0.7900 - val_loss: 0.6218 - learning_rate: 1.0000e-06
#               precision    recall  f1-score   support
#
#        akiec       1.00      0.33      0.50        18
#          bcc       0.76      0.62      0.68        26
#          bkl       0.53      0.75      0.62        57
#           df       1.00      0.33      0.50         6
#          mel       0.47      0.55      0.51        44
#           nv       0.93      0.90      0.91       343
#         vasc       0.75      0.50      0.60         6
#
#     accuracy                           0.81       500
#    macro avg       0.78      0.57      0.62       500
# weighted avg       0.83      0.81      0.81       500
#
# Saved: /content/runs/efficientnet/e40_b32
# [master] Appended summary to: /content/runs/efficientnet/experiments_master.csv

# %%
import json
import matplotlib.pyplot as plt

# Load history
with open("/content/runs/efficientnet/e40_b32/history.json") as f:
    history = json.load(f)

epochs = range(1, len(history['accuracy'])+1)

# Accuracy
plt.figure(figsize=(8,5))
plt.plot(epochs, history['accuracy'], label='Train Accuracy')
plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.figure(figsize=(8,5))
plt.plot(epochs, history['loss'], label='Train Loss')
plt.plot(epochs, history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os

def plot_accuracy_from_saved_run(run_path):
    """
    Plot accuracy graph from saved EfficientNet run
    """
    # Try to load from CSV first
    csv_path = os.path.join(run_path, "history_epoch.csv")
    json_path = os.path.join(run_path, "history.json")

    if os.path.exists(csv_path):
        df = pd.read_csv(csv_path)
        epochs = df['epoch'].values
        train_acc = df['accuracy'].values
        val_acc = df['val_accuracy'].values
        print(f"Loaded data from CSV: {len(epochs)} epochs")
    elif os.path.exists(json_path):
        with open(json_path, 'r') as f:
            history = json.load(f)
        train_acc = history.get('accuracy', [])
        val_acc = history.get('val_accuracy', [])
        epochs = range(1, len(train_acc) + 1)
        print(f"Loaded data from JSON: {len(epochs)} epochs")
    else:
        print("No history file found. Using extracted data from log.")
        return

    # Create the accuracy graph
    plt.figure(figsize=(12, 8))

    # Plot training and validation accuracy
    plt.plot(epochs, train_acc, 'b-', linewidth=2.5, label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r-', linewidth=2.5, label='Validation Accuracy')

    # Customize the graph
    plt.title('EfficientNet Model Accuracy', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend(loc='lower right', fontsize=12)

    # Set appropriate limits
    y_min = min(min(train_acc), min(val_acc)) - 0.05
    y_max = max(max(train_acc), max(val_acc)) + 0.05
    plt.ylim(max(0, y_min), min(1.0, y_max))

    # Add grid
    plt.grid(True, alpha=0.3)

    # Improve layout
    plt.tight_layout()

    # Save the plot
    plt.savefig('efficientnet_accuracy_graph.png', dpi=300, bbox_inches='tight')

    plt.show()

    # Print statistics
    print(f"Final Training Accuracy: {train_acc[-1]:.4f}")
    print(f"Final Validation Accuracy: {val_acc[-1]:.4f}")
    print(f"Best Validation Accuracy: {max(val_acc):.4f}")

plot_accuracy_from_saved_run('/content/runs/efficientnet/e40_b32')
# Out:
# Loaded data from CSV: 22 epochs
# Final Training Accuracy: 0.9160
# Final Validation Accuracy: 0.7900
# Best Validation Accuracy: 0.7940

# %%
#Save results back to Drive (persistent)

# Save all runs
# !mkdir -p "/content/drive/MyDrive/SKIN_CANCER_RESULTS/EfficientNet"
# !rsync -ah --info=progress2 "/content/runs/" "/content/drive/MyDrive/SKIN_CANCER_RESULTS/EfficientNet"

# Inspect what's saved
# !find "/content/drive/MyDrive/SKIN_CANCER_RESULTS" -maxdepth 3 -type f | head -n 20
# Out:
#          93.78M 100%  193.59MB/s    0:00:00 (xfr#14, to-chk=0/19)
# /content/drive/MyDrive/SKIN_CANCER_RESULTS/EfficientNet/efficientnet/experiments_master.csv
