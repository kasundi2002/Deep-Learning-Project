# %% [markdown]
# # **Mihiduni**- DenseNet121 (transfer + class weights)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check GPU
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Basic deps for the split script + training
# !pip -q install pandas scikit-learn tqdm

# %%
#1) Mount Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#2) Define paths to your files in root of My Drive and copy to fast local SSD
# Paths on Drive (root)
ZIP1 = "/content/drive/MyDrive/HAM10000_images_part_1.zip"
ZIP2 = "/content/drive/MyDrive/HAM10000_images_part_2.zip"
META = "/content/drive/MyDrive/HAM10000_metadata.csv"

# Local working area on Colab SSD
WORK     = "/content/work"
RAW_DIR  = f"{WORK}/raw"
EXTRACT  = f"{WORK}/ham10000_extracted"
DATA_DIR = f"{WORK}/data"

import os, subprocess, pathlib
os.makedirs(RAW_DIR, exist_ok=True)
os.makedirs(EXTRACT, exist_ok=True)
os.makedirs(DATA_DIR, exist_ok=True)

# Copy only if missing (fast on later sessions)
print(subprocess.getoutput(f'rsync -ah --ignore-existing "{ZIP1}" "{ZIP2}" "{META}" "{RAW_DIR}/"'))
print("Local RAW_DIR:", subprocess.getoutput(f'ls -lh "{RAW_DIR}"'))
# Out:
# Local RAW_DIR: total 2.6G
# -rw------- 1 root root 1.3G Oct  8 23:17 HAM10000_images_part_1.zip
# -rw------- 1 root root 1.4G Oct  8 23:45 HAM10000_images_part_2.zip
# -rw------- 1 root root 551K Oct  8 23:57 HAM10000_metadata.csv

# %%
#3) Unzip locally (NOT to Drive)
# !mkdir -p /content/work/ham10000_extracted
# !unzip -q /content/work/raw/HAM10000_images_part_1.zip -d /content/work/ham10000_extracted/
# !unzip -q /content/work/raw/HAM10000_images_part_2.zip -d /content/work/ham10000_extracted/
# !ls -lh /content/work/ham10000_extracted | head
# Out:
# total 328K
# drwxr-xr-x 2 root root 156K Sep 29 20:38 HAM10000_images_part_1
# drwxrwxrwx 2 root root 164K Sep 29 15:08 HAM10000_images_part_2

# %%
# !mkdir -p /content/scripts

# %%
# %%writefile /content/scripts/split_ham10000.py
#!/usr/bin/env python3
import argparse, os, shutil, zipfile
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def unzip_if_needed(zip_path: Path, extract_dir: Path):
    extract_dir.mkdir(parents=True, exist_ok=True)
    # If any jpgs already exist anywhere under extract_dir, skip
    if any(extract_dir.rglob("*.jpg")):
        print(f"[skip] Images already present under: {extract_dir}")
        return
    assert zip_path.exists(), f"Missing: {zip_path}"
    print(f"[unzip] {zip_path.name} -> {extract_dir}")
    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(extract_dir)

def index_images(img_root: Path):
    """
    Build a dict: image_id (without .jpg) -> full path
    Recurses under img_root to handle both 'HAM10000_images' and '..._part_1/part_2' layouts.
    """
    mapping = {}
    for p in img_root.rglob("*.jpg"):
        mapping[p.stem] = str(p)
    return mapping

def build_splits(meta_csv: Path, img_root: Path, train_pct: float, val_pct: float, test_pct: float, seed: int):
    assert abs((train_pct + val_pct + test_pct) - 1.0) < 1e-6, "Splits must sum to 1.0"
    meta = pd.read_csv(meta_csv)
    img_map = index_images(img_root)
    meta["image_path"] = meta["image_id"].map(img_map)
    meta = meta.dropna(subset=["image_path"]).copy()

    # quick sanity
    print(f"[info] Found {len(img_map)} jpgs under {img_root}")
    print(f"[info] Matched rows with metadata: {len(meta)}")

    train_df, temp_df = train_test_split(
        meta, test_size=1.0-train_pct, stratify=meta["dx"], random_state=seed
    )
    test_rel = test_pct / (val_pct + test_pct)
    val_df, test_df = train_test_split(
        temp_df, test_size=test_rel, stratify=temp_df["dx"], random_state=seed
    )
    return train_df, val_df, test_df, sorted(meta["dx"].unique())

def materialize_split(df: pd.DataFrame, split_name: str, out_root: Path):
    base = out_root / split_name
    base.mkdir(parents=True, exist_ok=True)
    for cls in sorted(df["dx"].unique()):
        (base / cls).mkdir(parents=True, exist_ok=True)
    for _, r in tqdm(df.iterrows(), total=len(df), desc=f"{split_name:>5}", unit="img"):
        src = Path(r["image_path"])
        dst = base / r["dx"] / src.name
        if not dst.exists():
            shutil.copy2(src, dst)

def print_counts(data_dir: Path):
    for split in ["train", "val", "test"]:
        base = data_dir / split
        if base.exists():
            counts = {
                d.name: len(list((base / d).glob("*")))
                for d in base.iterdir() if d.is_dir()
            }
            print(split, counts)

def main():
    p = argparse.ArgumentParser()
    p.add_argument("--project_dir", default=".")
    p.add_argument("--train", type=float, default=0.8)
    p.add_argument("--val",   type=float, default=0.1)
    p.add_argument("--test",  type=float, default=0.1)
    p.add_argument("--seed",  type=int, default=42)
    p.add_argument("--clean", action="store_true")
    args = p.parse_args()

    project = Path(args.project_dir).resolve()
    raw_dir  = project / "raw"
    data_dir = project / "data"
    extract  = project / "ham10000_extracted"   # we recurse under this folder
    imgs_root = extract                         # <-- recursive root

    part1 = raw_dir / "HAM10000_images_part_1.zip"
    part2 = raw_dir / "HAM10000_images_part_2.zip"
    meta  = raw_dir / "HAM10000_metadata.csv"

    extract.mkdir(parents=True, exist_ok=True)
    data_dir.mkdir(parents=True, exist_ok=True)

    unzip_if_needed(part1, extract)
    unzip_if_needed(part2, extract)

    train_df, val_df, test_df, classes = build_splits(
        meta, imgs_root, args.train, args.val, args.test, args.seed
    )

    if args.clean:
        for s in ["train", "val", "test"]:
            target = data_dir / s
            if target.exists():
                shutil.rmtree(target)

    materialize_split(train_df, "train", data_dir)
    materialize_split(val_df, "val", data_dir)
    materialize_split(test_df, "test", data_dir)
    print_counts(data_dir)
    print("[done] Data ready at:", data_dir)

if __name__ == "__main__":
    main()
# Out:
# Writing /content/scripts/split_ham10000.py

# %%
# !python /content/scripts/split_ham10000.py \
  --project_dir "/content/work" \
  --train 0.8 --val 0.1 --test 0.1 --seed 42 --clean
# Out:
# [skip] Images already present under: /content/work/ham10000_extracted
# [skip] Images already present under: /content/work/ham10000_extracted
# [info] Found 10015 jpgs under /content/work/ham10000_extracted
# [info] Matched rows with metadata: 10015
# train: 100% 8012/8012 [00:15<00:00, 519.79img/s]
#   val: 100% 1001/1001 [00:02<00:00, 394.79img/s]
#  test: 100% 1002/1002 [00:02<00:00, 454.65img/s]
# train {'vasc': 114, 'mel': 890, 'akiec': 262, 'nv': 5364, 'bcc': 411, 'bkl': 879, 'df': 92}
# val {'vasc': 14, 'mel': 111, 'akiec': 33, 'nv': 670, 'bcc': 51, 'bkl': 110, 'df': 12}
# test {'vasc': 14, 'mel': 112, 'akiec': 32, 'nv': 671, 'bcc': 52, 'bkl': 110, 'df': 11}
# [done] Data ready at: /content/work/data

# %%
#Quick sanity check:
import os
for split in ("train","val","test"):
    base = os.path.join("/content/work/data", split)
    classes = [d for d in sorted(os.listdir(base)) if os.path.isdir(os.path.join(base,d))]
    counts = {c: len(os.listdir(os.path.join(base,c))) for c in classes}
    print(split, counts)
# Out:
# train {'akiec': 262, 'bcc': 411, 'bkl': 879, 'df': 92, 'mel': 890, 'nv': 5364, 'vasc': 114}
# val {'akiec': 33, 'bcc': 51, 'bkl': 110, 'df': 12, 'mel': 111, 'nv': 670, 'vasc': 14}
# test {'akiec': 32, 'bcc': 52, 'bkl': 110, 'df': 11, 'mel': 112, 'nv': 671, 'vasc': 14}

# %%
import os
print("Exists:", os.path.isdir("/content/work/data"))
print("Splits:", os.listdir("/content/work/data"))
# Out:
# Exists: True
# Splits: ['val', 'train', 'test']

# %%
# make sure the folder exists
# !mkdir -p /content/members

# %%
# %%writefile /content/members/run_densenet121.py
#!/usr/bin/env python3
import os, json, time, argparse, csv, datetime
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score

MODEL_DIR = "densenet121"  # model-specific folder and master CSV

def get_datasets(data_dir, img_size=(224,224), batch=32, seed=42, binary=False):
    def loader(split, shuffle):
        return tf.keras.utils.image_dataset_from_directory(
            os.path.join(data_dir, split),
            image_size=img_size, batch_size=batch, seed=seed, shuffle=shuffle
        )
    ds_train = loader("train", True)
    ds_val   = loader("val", False)
    ds_test  = loader("test", False)
    class_names = ds_train.class_names

    aug = keras.Sequential([
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.05),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1),
    ])

    ds_train = ds_train.map(lambda x,y:(aug(x), y), num_parallel_calls=tf.data.AUTOTUNE)
    ds_train = ds_train.cache().prefetch(tf.data.AUTOTUNE)
    ds_val   = ds_val.cache().prefetch(tf.data.AUTOTUNE)
    ds_test  = ds_test.cache().prefetch(tf.data.AUTOTUNE)
    return ds_train, ds_val, ds_test, class_names, bool(binary)

def compute_class_weights(ds, n_classes):
    counts = np.zeros(n_classes, dtype=np.int64)
    for _, y in ds.unbatch():
        counts[int(y.numpy())] += 1
    tot = counts.sum()
    return {i: float(tot / (n_classes * max(counts[i], 1))) for i in range(n_classes)}

def build_model(num_classes, img_size=(224,224), binary=False):
    from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input
    inp = keras.Input(shape=(*img_size, 3))
    x = preprocess_input(inp)
    base = DenseNet121(include_top=False, weights="imagenet", input_tensor=x)
    x = layers.GlobalAveragePooling2D()(base.output)
    x = layers.Dropout(0.3)(x)
    out = layers.Dense(1, activation="sigmoid", dtype="float32")(x) if binary \
          else layers.Dense(num_classes, activation="softmax", dtype="float32")(x)
    model = keras.Model(inp, out)
    return model, base

def compile_and_fit(model, train_ds, val_ds, *, loss, lr, epochs, class_weight, ckpt_path):
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=lr),
                  loss=loss, metrics=["accuracy"])
    os.makedirs(os.path.dirname(ckpt_path), exist_ok=True)
    cbs = [
        keras.callbacks.ModelCheckpoint(ckpt_path, save_best_only=True,
                                        monitor="val_accuracy", mode="max"),
        keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True,
                                      monitor="val_accuracy", mode="max"),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.3,
                                          patience=2, min_lr=1e-6, verbose=1),
    ]
    hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs,
                     class_weight=class_weight, callbacks=cbs)
    return {k: [float(v) for v in vals] for k, vals in hist.history.items()}

def eval_save(model, ds_test, names, out_dir, binary=False):
    y_true, y_pred = [], []
    for x, y in ds_test:
        p = model.predict(x, verbose=0)
        yp = (p.reshape(-1) >= 0.5).astype(int) if binary else p.argmax(axis=1)
        y_true += y.numpy().tolist(); y_pred += yp.tolist()
    y_true = np.array(y_true); y_pred = np.array(y_pred)

    acc = float(accuracy_score(y_true, y_pred))
    f1  = float(f1_score(y_true, y_pred, average=("binary" if binary else "macro")))
    rep = classification_report(y_true, y_pred, target_names=names)
    cm  = confusion_matrix(y_true, y_pred).tolist()

    os.makedirs(out_dir, exist_ok=True)
    json.dump({"accuracy": acc, "macro_f1": f1, "confusion_matrix": cm},
              open(os.path.join(out_dir, "metrics.json"), "w"), indent=2)
    open(os.path.join(out_dir, "classification_report.txt"), "w").write(rep)
    json.dump(names, open(os.path.join(out_dir, "classes.json"), "w"), indent=2)

    print(rep); print("Saved:", out_dir)
    return acc, f1

def write_epoch_csv(history, path_csv):
    import pandas as pd
    n = max(len(history.get("accuracy",[])), len(history.get("loss",[])))
    rows = [{
        "epoch": i+1,
        "accuracy": history.get("accuracy",[None]*n)[i],
        "loss": history.get("loss",[None]*n)[i],
        "val_accuracy": history.get("val_accuracy",[None]*n)[i],
        "val_loss": history.get("val_loss",[None]*n)[i],
    } for i in range(n)]
    pd.DataFrame(rows).to_csv(path_csv, index=False)

def append_master_row(master_csv, row):
    headers = ["timestamp","run_name","data","img_size","batch","warmup","epochs",
               "unfreeze","base_lr","ft_lr","binary","best_val_acc","best_val_loss",
               "test_acc","test_macro_f1"]
    os.makedirs(os.path.dirname(master_csv), exist_ok=True)
    new = not os.path.isfile(master_csv)
    with open(master_csv, "a", newline="") as f:
        w = csv.DictWriter(f, fieldnames=headers)
        if new: w.writeheader()
        w.writerow({k: row.get(k) for k in headers})

def main(a):
    run = a.run_name or time.strftime("%Y%m%d-%H%M%S")
    out_root = a.out_dir or "runs"
    model_root = os.path.join(out_root, MODEL_DIR)
    out = os.path.join(model_root, run)
    os.makedirs(out, exist_ok=True)

    ds_tr, ds_va, ds_te, names, binary = get_datasets(a.data, (a.size, a.size), a.batch, binary=bool(a.binary))
    ncls = 2 if binary else len(names)
    class_weight = compute_class_weights(ds_tr, ncls)

    model, base = build_model(ncls, (a.size, a.size), binary)
    loss = "binary_crossentropy" if binary else keras.losses.SparseCategoricalCrossentropy()

    # Phase 1: warmup
    base.trainable = False
    hist_warm = compile_and_fit(model, ds_tr, ds_va, loss=loss, lr=a.base_lr,
                                epochs=max(1, a.warmup), class_weight=class_weight,
                                ckpt_path=os.path.join(out, "best.keras"))

    # Phase 2: fine-tune (partial unfreeze)
    base.trainable = True
    if a.unfreeze > 0 and a.unfreeze < len(base.layers):
        for l in base.layers[:-a.unfreeze]:
            l.trainable = False
    hist_ft = compile_and_fit(model, ds_tr, ds_va, loss=loss, lr=a.ft_lr,
                              epochs=a.epochs, class_weight=class_weight,
                              ckpt_path=os.path.join(out, "best.keras"))

    # Save histories
    history = {}
    for k in set(list(hist_warm.keys()) + list(hist_ft.keys())):
        history[k] = (hist_warm.get(k, []) + hist_ft.get(k, []))
    json.dump(history, open(os.path.join(out, "history.json"), "w"), indent=2)
    write_epoch_csv(history, os.path.join(out, "history_epoch.csv"))

    # Evaluate & save reports
    test_acc, test_f1 = eval_save(model, ds_te, names, out, binary)

    # Model-specific master CSV
    best_idx = int(np.nanargmax(history.get("val_accuracy", [np.nan])))
    best_val_acc  = float(history["val_accuracy"][best_idx]) if "val_accuracy" in history else None
    best_val_loss = float(history["val_loss"][best_idx]) if "val_loss" in history else None
    master_csv = os.path.join(model_root, "experiments_master.csv")
    append_master_row(master_csv, {
        "timestamp": datetime.datetime.now().isoformat(timespec="seconds"),
        "run_name": run,
        "data": a.data, "img_size": a.size, "batch": a.batch,
        "warmup": a.warmup, "epochs": a.epochs, "unfreeze": a.unfreeze,
        "base_lr": a.base_lr, "ft_lr": a.ft_lr, "binary": int(a.binary),
        "best_val_acc": best_val_acc, "best_val_loss": best_val_loss,
        "test_acc": test_acc, "test_macro_f1": test_f1
    })
    print(f"[master] Appended summary to: {master_csv}")

if __name__ == "__main__":
    ap = argparse.ArgumentParser()
    # default so you don't hit the --data error
    ap.add_argument("--data", default=os.environ.get("DATA_DIR", "/content/work/data"))
    ap.add_argument("--epochs", type=int, default=25)
    ap.add_argument("--warmup", type=int, default=3)
    ap.add_argument("--size", type=int, default=224)
    ap.add_argument("--batch", type=int, default=32)
    ap.add_argument("--base_lr", type=float, default=1e-4)
    ap.add_argument("--ft_lr", type=float, default=1e-5)
    ap.add_argument("--unfreeze", type=int, default=50)  # last ~50 layers
    ap.add_argument("--binary", type=int, default=0)
    ap.add_argument("--run_name", default="")
    ap.add_argument("--out_dir", default="runs")
    a = ap.parse_args(); main(a)
# Out:
# Writing /content/members/run_densenet121.py

# %%
# baseline
# !python /content/members/run_densenet121.py \
  --data "/content/work/data" \
  --epochs 40 --warmup 6 --unfreeze 80 \
  --batch 25 --base_lr 1e-4 --ft_lr 1e-5
# Out:
# 2025-10-12 11:06:48.225476: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760267208.246863    2698 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760267208.254417    2698 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760267208.270356    2698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760267208.270388    2698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760267208.270392    2698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760267208.270397    2698 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 8012 files belonging to 7 classes.
# 2025-10-12 11:06:53.251821: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1760267213.254773    2698 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Found 1001 files belonging to 7 classes.
# Found 1002 files belonging to 7 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/6
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760267348.523003    2744 service.cc:152] XLA service 0x7e0ba8002fc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760267348.523039    2744 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760267351.896723    2744 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1760267364.672656    2744 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 89s 191ms/step - accuracy: 0.1414 - loss: 2.3464 - val_accuracy: 0.2358 - val_loss: 1.8455 - learning_rate: 1.0000e-04
# Epoch 2/6
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.2381 - loss: 2.1041 - val_accuracy: 0.3976 - val_loss: 1.6298 - learning_rate: 1.0000e-04
# Epoch 3/6
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.3173 - loss: 1.9132 - val_accuracy: 0.5125 - val_loss: 1.4619 - learning_rate: 1.0000e-04
# Epoch 4/6
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 21s 65ms/step - accuracy: 0.3689 - loss: 1.8001 - val_accuracy: 0.5075 - val_loss: 1.4276 - learning_rate: 1.0000e-04
# Epoch 5/6
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.4118 - loss: 1.7100 - val_accuracy: 0.5325 - val_loss: 1.3477 - learning_rate: 1.0000e-04
# Epoch 6/6
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.4516 - loss: 1.6388 - val_accuracy: 0.5514 - val_loss: 1.2926 - learning_rate: 1.0000e-04
# Epoch 1/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 112s 215ms/step - accuracy: 0.3305 - loss: 1.7188 - val_accuracy: 0.4955 - val_loss: 1.3801 - learning_rate: 1.0000e-05
# Epoch 2/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.4407 - loss: 1.4642 - val_accuracy: 0.5514 - val_loss: 1.2596 - learning_rate: 1.0000e-05
# Epoch 3/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.5012 - loss: 1.3070 - val_accuracy: 0.5664 - val_loss: 1.2000 - learning_rate: 1.0000e-05
# Epoch 4/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 24s 76ms/step - accuracy: 0.5367 - loss: 1.1997 - val_accuracy: 0.5854 - val_loss: 1.1455 - learning_rate: 1.0000e-05
# Epoch 5/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.5613 - loss: 1.0916 - val_accuracy: 0.6014 - val_loss: 1.0931 - learning_rate: 1.0000e-05
# Epoch 6/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.5935 - loss: 1.0465 - val_accuracy: 0.6224 - val_loss: 1.0584 - learning_rate: 1.0000e-05
# Epoch 7/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.6058 - loss: 0.9598 - val_accuracy: 0.6354 - val_loss: 1.0219 - learning_rate: 1.0000e-05
# Epoch 8/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 79ms/step - accuracy: 0.6168 - loss: 0.9156 - val_accuracy: 0.6384 - val_loss: 1.0084 - learning_rate: 1.0000e-05
# Epoch 9/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - accuracy: 0.6342 - loss: 0.8708 - val_accuracy: 0.6563 - val_loss: 0.9682 - learning_rate: 1.0000e-05
# Epoch 10/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 79ms/step - accuracy: 0.6491 - loss: 0.8288 - val_accuracy: 0.6623 - val_loss: 0.9503 - learning_rate: 1.0000e-05
# Epoch 11/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.6656 - loss: 0.7727 - val_accuracy: 0.6693 - val_loss: 0.9312 - learning_rate: 1.0000e-05
# Epoch 12/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.6675 - loss: 0.7325 - val_accuracy: 0.6723 - val_loss: 0.9144 - learning_rate: 1.0000e-05
# Epoch 13/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - accuracy: 0.6882 - loss: 0.6941 - val_accuracy: 0.6713 - val_loss: 0.9076 - learning_rate: 1.0000e-05
# Epoch 14/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.7021 - loss: 0.6355 - val_accuracy: 0.6763 - val_loss: 0.8927 - learning_rate: 1.0000e-05
# Epoch 15/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.7138 - loss: 0.6276 - val_accuracy: 0.6753 - val_loss: 0.8960 - learning_rate: 1.0000e-05
# Epoch 16/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 78ms/step - accuracy: 0.7202 - loss: 0.5872 - val_accuracy: 0.6853 - val_loss: 0.8661 - learning_rate: 1.0000e-05
# Epoch 17/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.7372 - loss: 0.5403 - val_accuracy: 0.6893 - val_loss: 0.8551 - learning_rate: 1.0000e-05
# Epoch 18/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.7387 - loss: 0.5326 - val_accuracy: 0.6943 - val_loss: 0.8468 - learning_rate: 1.0000e-05
# Epoch 19/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.7612 - loss: 0.4787 - val_accuracy: 0.6923 - val_loss: 0.8405 - learning_rate: 1.0000e-05
# Epoch 20/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.7671 - loss: 0.4661 - val_accuracy: 0.6963 - val_loss: 0.8357 - learning_rate: 1.0000e-05
# Epoch 21/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.7706 - loss: 0.4471 - val_accuracy: 0.6993 - val_loss: 0.8107 - learning_rate: 1.0000e-05
# Epoch 22/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - accuracy: 0.7826 - loss: 0.4283 - val_accuracy: 0.7023 - val_loss: 0.8183 - learning_rate: 1.0000e-05
# Epoch 23/40
# 320/321 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7817 - loss: 0.4087
# Epoch 23: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.7818 - loss: 0.4086 - val_accuracy: 0.6963 - val_loss: 0.8297 - learning_rate: 1.0000e-05
# Epoch 24/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - accuracy: 0.7912 - loss: 0.3794 - val_accuracy: 0.6973 - val_loss: 0.8244 - learning_rate: 3.0000e-06
# Epoch 25/40
# 320/321 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7890 - loss: 0.3727
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-06.
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.7890 - loss: 0.3727 - val_accuracy: 0.6993 - val_loss: 0.8200 - learning_rate: 3.0000e-06
# Epoch 26/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - accuracy: 0.7964 - loss: 0.3640 - val_accuracy: 0.6993 - val_loss: 0.8211 - learning_rate: 1.0000e-06
# Epoch 27/40
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 24s 74ms/step - accuracy: 0.7971 - loss: 0.3624 - val_accuracy: 0.6993 - val_loss: 0.8224 - learning_rate: 1.0000e-06
#               precision    recall  f1-score   support
#
#        akiec       0.80      0.25      0.38        32
#          bcc       0.69      0.56      0.62        52
#          bkl       0.43      0.85      0.57       110
#           df       0.25      0.73      0.37        11
#          mel       0.39      0.44      0.41       112
#           nv       0.94      0.79      0.86       671
#         vasc       0.75      0.86      0.80        14
#
#     accuracy                           0.72      1002
#    macro avg       0.61      0.64      0.57      1002
# weighted avg       0.80      0.72      0.74      1002
#
# Saved: runs/densenet121/20251012-110652
# [master] Appended summary to: runs/densenet121/experiments_master.csv

# %%
# smaller batch
# !python /content/members/run_densenet121.py \
  --data "/content/work/data" \
  --epochs 40 --warmup 3 --unfreeze 70 \
  --batch 16 --base_lr 1e-4 --ft_lr 1e-5 \
  --out_dir /content/runs --run_name e25_b16
# Out:
# 2025-10-12 11:26:11.371844: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760268371.411386    8421 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760268371.423349    8421 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760268371.457393    8421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760268371.457575    8421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760268371.457653    8421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1760268371.457665    8421 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 8012 files belonging to 7 classes.
# 2025-10-12 11:26:19.866282: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1760268379.866448    8421 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Found 1001 files belonging to 7 classes.
# Found 1002 files belonging to 7 classes.
# Epoch 1/3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760268508.442009    8490 service.cc:152] XLA service 0x7c6fc80026c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760268508.442048    8490 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760268511.903327    8490 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1760268523.519766    8490 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 92s 132ms/step - accuracy: 0.1643 - loss: 2.4293 - val_accuracy: 0.3796 - val_loss: 1.7457 - learning_rate: 1.0000e-04
# Epoch 2/3
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 49ms/step - accuracy: 0.2750 - loss: 2.0583 - val_accuracy: 0.4615 - val_loss: 1.5752 - learning_rate: 1.0000e-04
# Epoch 3/3
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 24s 48ms/step - accuracy: 0.3513 - loss: 1.9199 - val_accuracy: 0.5175 - val_loss: 1.4468 - learning_rate: 1.0000e-04
# Epoch 1/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 112s 140ms/step - accuracy: 0.3625 - loss: 1.8147 - val_accuracy: 0.5445 - val_loss: 1.3202 - learning_rate: 1.0000e-05
# Epoch 2/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 54ms/step - accuracy: 0.4336 - loss: 1.5458 - val_accuracy: 0.5734 - val_loss: 1.2397 - learning_rate: 1.0000e-05
# Epoch 3/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.4616 - loss: 1.4250 - val_accuracy: 0.6064 - val_loss: 1.1530 - learning_rate: 1.0000e-05
# Epoch 4/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.5296 - loss: 1.2367 - val_accuracy: 0.6144 - val_loss: 1.1131 - learning_rate: 1.0000e-05
# Epoch 5/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.5540 - loss: 1.1582 - val_accuracy: 0.6234 - val_loss: 1.0773 - learning_rate: 1.0000e-05
# Epoch 6/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.5703 - loss: 1.0941 - val_accuracy: 0.6354 - val_loss: 1.0271 - learning_rate: 1.0000e-05
# Epoch 7/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.5903 - loss: 1.0083 - val_accuracy: 0.6434 - val_loss: 1.0033 - learning_rate: 1.0000e-05
# Epoch 8/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 54ms/step - accuracy: 0.6151 - loss: 0.9549 - val_accuracy: 0.6494 - val_loss: 0.9740 - learning_rate: 1.0000e-05
# Epoch 9/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 54ms/step - accuracy: 0.6386 - loss: 0.8697 - val_accuracy: 0.6573 - val_loss: 0.9524 - learning_rate: 1.0000e-05
# Epoch 10/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.6450 - loss: 0.8419 - val_accuracy: 0.6623 - val_loss: 0.9286 - learning_rate: 1.0000e-05
# Epoch 11/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6673 - loss: 0.7791 - val_accuracy: 0.6803 - val_loss: 0.9096 - learning_rate: 1.0000e-05
# Epoch 12/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.6692 - loss: 0.7361 - val_accuracy: 0.6823 - val_loss: 0.9065 - learning_rate: 1.0000e-05
# Epoch 13/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 54ms/step - accuracy: 0.6933 - loss: 0.6970 - val_accuracy: 0.6913 - val_loss: 0.8914 - learning_rate: 1.0000e-05
# Epoch 14/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.6977 - loss: 0.6592 - val_accuracy: 0.6953 - val_loss: 0.8835 - learning_rate: 1.0000e-05
# Epoch 15/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.7079 - loss: 0.6074 - val_accuracy: 0.6993 - val_loss: 0.8604 - learning_rate: 1.0000e-05
# Epoch 16/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - accuracy: 0.7215 - loss: 0.5774 - val_accuracy: 0.6993 - val_loss: 0.8591 - learning_rate: 1.0000e-05
# Epoch 17/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.7399 - loss: 0.5418 - val_accuracy: 0.7053 - val_loss: 0.8453 - learning_rate: 1.0000e-05
# Epoch 18/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.7410 - loss: 0.5152 - val_accuracy: 0.7083 - val_loss: 0.8497 - learning_rate: 1.0000e-05
# Epoch 19/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.7595 - loss: 0.4833 - val_accuracy: 0.7103 - val_loss: 0.8384 - learning_rate: 1.0000e-05
# Epoch 20/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.7627 - loss: 0.4519 - val_accuracy: 0.7033 - val_loss: 0.8261 - learning_rate: 1.0000e-05
# Epoch 21/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.7689 - loss: 0.4189 - val_accuracy: 0.7073 - val_loss: 0.8275 - learning_rate: 1.0000e-05
# Epoch 22/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7769 - loss: 0.4030
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.7769 - loss: 0.4030 - val_accuracy: 0.7043 - val_loss: 0.8289 - learning_rate: 1.0000e-05
# Epoch 23/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.7946 - loss: 0.3873 - val_accuracy: 0.7103 - val_loss: 0.8392 - learning_rate: 3.0000e-06
# Epoch 24/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7910 - loss: 0.3677
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-06.
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.7910 - loss: 0.3677 - val_accuracy: 0.7123 - val_loss: 0.8412 - learning_rate: 3.0000e-06
# Epoch 25/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.7889 - loss: 0.3661 - val_accuracy: 0.7103 - val_loss: 0.8392 - learning_rate: 1.0000e-06
# Epoch 26/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.7858 - loss: 0.3656 - val_accuracy: 0.7123 - val_loss: 0.8404 - learning_rate: 1.0000e-06
# Epoch 27/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.7937 - loss: 0.3573 - val_accuracy: 0.7123 - val_loss: 0.8404 - learning_rate: 1.0000e-06
# Epoch 28/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.7909 - loss: 0.3567 - val_accuracy: 0.7133 - val_loss: 0.8391 - learning_rate: 1.0000e-06
# Epoch 29/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 27s 53ms/step - accuracy: 0.7927 - loss: 0.3548 - val_accuracy: 0.7153 - val_loss: 0.8382 - learning_rate: 1.0000e-06
# Epoch 30/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.7939 - loss: 0.3392 - val_accuracy: 0.7123 - val_loss: 0.8387 - learning_rate: 1.0000e-06
# Epoch 31/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.7991 - loss: 0.3564 - val_accuracy: 0.7143 - val_loss: 0.8372 - learning_rate: 1.0000e-06
# Epoch 32/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.8013 - loss: 0.3437 - val_accuracy: 0.7143 - val_loss: 0.8362 - learning_rate: 1.0000e-06
# Epoch 33/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - accuracy: 0.7956 - loss: 0.3509 - val_accuracy: 0.7143 - val_loss: 0.8374 - learning_rate: 1.0000e-06
# Epoch 34/40
# 501/501 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.7968 - loss: 0.3500 - val_accuracy: 0.7143 - val_loss: 0.8378 - learning_rate: 1.0000e-06
#               precision    recall  f1-score   support
#
#        akiec       0.67      0.31      0.43        32
#          bcc       0.65      0.63      0.64        52
#          bkl       0.38      0.88      0.53       110
#           df       0.44      0.36      0.40        11
#          mel       0.39      0.42      0.41       112
#           nv       0.95      0.77      0.85       671
#         vasc       0.77      0.71      0.74        14
#
#     accuracy                           0.71      1002
#    macro avg       0.61      0.58      0.57      1002
# weighted avg       0.79      0.71      0.73      1002
#
# Saved: /content/runs/densenet121/e25_b16
# [master] Appended summary to: /content/runs/densenet121/experiments_master.csv

# %%
#Save results back to Drive (persistent)

# Save all runs
# !mkdir -p "/content/drive/MyDrive/SKIN_CANCER_RESULTS/DenseNet"
# !rsync -ah --info=progress2 "/content/runs/" "/content/drive/MyDrive/SKIN_CANCER_RESULTS/DenseNet"

# Inspect what's saved
# !find "/content/drive/MyDrive/SKIN_CANCER_RESULTS" -maxdepth 3 -type f | head -n 20
# Out:
#          84.20M 100%  137.74MB/s    0:00:00 (xfr#13, to-chk=0/17)
# /content/drive/MyDrive/SKIN_CANCER_RESULTS/DenseNet/densenet121/experiments_master.csv

# %%
import json
import matplotlib.pyplot as plt

# Load history
with open("/content/runs/densenet121/e25_b16/history.json") as f:
    history = json.load(f)

epochs = range(1, len(history['accuracy'])+1)

# Accuracy
plt.figure(figsize=(8,5))
plt.plot(epochs, history['accuracy'], label='Train Accuracy')
plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.figure(figsize=(8,5))
plt.plot(epochs, history['loss'], label='Train Loss')
plt.plot(epochs, history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load history
with open("/content/runs/densenet121/20251012-110652/history.json") as f:
    history = json.load(f)

epochs = range(1, len(history['accuracy'])+1)

# Accuracy
plt.figure(figsize=(8,5))
plt.plot(epochs, history['accuracy'], label='Train Accuracy')
plt.plot(epochs, history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Loss
plt.figure(figsize=(8,5))
plt.plot(epochs, history['loss'], label='Train Loss')
plt.plot(epochs, history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import json
import os

def plot_model_accuracy(run_path, model_name="DenseNet121"):
    """
    Plot training & validation accuracy from a saved run folder.
    It supports both CSV and JSON history formats.
    """
    csv_path = os.path.join(run_path, "history_epoch.csv")
    json_path = os.path.join(run_path, "history.json")

    # Load data
    if os.path.exists(csv_path):
        df = pd.read_csv(csv_path)
        epochs = df["epoch"].values if "epoch" in df.columns else range(1, len(df) + 1)
        train_acc = df["accuracy"].values
        val_acc = df["val_accuracy"].values
        print(f" Loaded history from CSV — {len(epochs)} epochs")

    elif os.path.exists(json_path):
        with open(json_path, "r") as f:
            history = json.load(f)
        train_acc = history.get("accuracy", [])
        val_acc = history.get("val_accuracy", [])
        epochs = range(1, len(train_acc) + 1)
        print(f" Loaded history from JSON — {len(epochs)} epochs")

    else:
        raise FileNotFoundError(f" No history file found in {run_path}")

    # Plot Accuracy Graph
    plt.figure(figsize=(10, 6))
    plt.plot(epochs, train_acc, 'b-', linewidth=2, label='Training Accuracy')
    plt.plot(epochs, val_acc, 'r--', linewidth=2, label='Validation Accuracy')

    plt.title(f"{model_name} Accuracy Model", fontsize=16, fontweight='bold')
    plt.xlabel("Epoch", fontsize=12)
    plt.ylabel("Accuracy", fontsize=12)
    plt.legend(fontsize=12)
    plt.grid(alpha=0.3)
    plt.tight_layout()

    # Save the plot
    save_path = os.path.join(run_path, f"{model_name}_accuracy_graph.png")
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

    print(f" Final Training Accuracy: {train_acc[-1]:.4f}")
    print(f" Final Validation Accuracy: {val_acc[-1]:.4f}")
    print(f" Best Validation Accuracy: {max(val_acc):.4f}")
    print(f" Graph saved at: {save_path}")

# Run this for your e25_b16 results
plot_model_accuracy("/content/drive/MyDrive/SKIN_CANCER_RESULTS/DenseNet/densenet121/e25_b16", "DenseNet121")
# Out:
#  Loaded history from CSV — 37 epochs
#  Final Training Accuracy: 0.7966
#  Final Validation Accuracy: 0.7143
#  Best Validation Accuracy: 0.7153
#  Graph saved at: /content/drive/MyDrive/SKIN_CANCER_RESULTS/DenseNet/densenet121/e25_b16/DenseNet121_accuracy_graph.png
